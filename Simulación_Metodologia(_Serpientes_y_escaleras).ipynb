# %% [markdown]
# # **Serpientes** **y** **escaleras**

# %% [markdown]
# Hallar el numero de tiradas promedio para terminar este juego \
# ![serpiente.jfif](data:image/jpeg;base64,...)

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
dado=0
p=0
moves=0
tirada=0
Lista=[]

# %%
def juego():
  p=0
  moves=0
  while p<=20:
    dado=random.randint(1,6)
    p=p+dado
    if p==3:
      p=11
    elif p==13:
      p=4
    elif p==15:
      p=19
    elif p==17:
      p=10
    moves=moves+1

  return(moves)

# %%
n=500
for i in range (n):
  Lista.append(juego())
  tirada=tirada+juego()

print("El número de tiradas promedio para completar el juego son de: ", tirada/n)
print("El promedio es: ", np.mean(Lista))
print("La varianza es: ", np.var(Lista))
print("La desviación estandar es: ", np.mean(Lista))
print("El intervalo de confianza es: ",
np.mean(Lista)-(1.96)*((np.var(Lista))/np.sqrt(n)), "≤",np.mean(Lista), " ≤",
np.mean(Lista)+(1.96)*((np.var(Lista))/np.sqrt(n)))
# Out:
# El número de tiradas promedio para completar el juego son de:  21.924
# El promedio es:  7.262666666666667
# La varianza es:  10.504339555555555
# La desviación estandar es:  7.262666666666667
# El intervalo de confianza es:  6.341920708312151 ≤ 7.262666666666667  ≤ 8.183412625021184
